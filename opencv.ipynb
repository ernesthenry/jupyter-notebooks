# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline
# %matplotlib qt

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline
# %matplotlib qt
# Read in image
image = cv2.imread('images/ernest.jpg')

# Print out the type of image data and its dimensions
print("This image is ", type(image),
     "with dimensions:", image.shape)
plt.imshow(image)
# Out:
# This image is  <class 'numpy.ndarray'> with dimensions: (309, 206, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2  # computer vision library

# %%
# Read in the image
image = cv2.imread('images/preacher.jpg')

# Print out the type of image data and its dimensions
print("This image is ", type(image),
     "with dimensions:", image.shape)
# Out:
# This image is  <class 'numpy.ndarray'> with dimensions: (640, 960, 3)

# %%
# %matplotlib inline

#Make the copy of the original image
image_copy = np.copy(image)

# Change from color to RGB (from BGR)
image_copy = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#Display the image    
plt.imshow(image_copy)

# %%
# Define color threshfold
lower_blue =np.array(0,0,230)
upper_blue =np.array(50,50, 255)

# %%
#Create mask
lower_blue =np.array(0,0,250)
upper_blue =np.array(50,70, 255)

#Define the masked area
mask = cv2.inRange(image_copy, lower_blue, upper_blue)

#Visualize mask
plt.imshow(mask, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-a8f3bc0b5340> in <module>
#       1 #Create mask
# ----> 2 lower_blue =np.array(0,0,250)
#       3 upper_blue =np.array(50,70, 255)
#       4
#       5 #Define the masked area
#
# ValueError: only 2 non-keyword arguments accepted

# %%
#Create mask
lower_blue =np.array(0,0,250)
upper_blue =np.array(50,70, 255)

#Define the masked area
mask = cv2.inRange(image_copy, lower_blue, upper_blue)

#Visualize mask
plt.imshow(mask, cmap="gray")
# Mask the image to let the pizza go through
masked_image = np.copy(image_copy)
masked_image[mask !=0] = [0,0,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-a9e363a214af> in <module>
#       1 #Create mask
# ----> 2 lower_blue =np.array(0,0,250)
#       3 upper_blue =np.array(50,70, 255)
#       4
#       5 #Define the masked area
#
# ValueError: only 2 non-keyword arguments accepted

# %%
#Load in backgroud image and covert to RGB
background_image = cv2.imread('images/enable.jpg')
background_image= cv2.cvtColor(background_image, cv2.COLOR_BGR2RGB)

#Crop it to the right size (514*816)
crop_background = background_image(0:514, 0:816)

#Mask the cropped background so that the picture area is blocked
crop_background[mask == 0] = [0,0,0]

#Dispaly the background
plt.imshow(crop_background)

#Add the two images together to create a complete image
complete_image = crop_background + masked_image
